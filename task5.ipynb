# %%
import pandas as pd

# %%
df = pd.read_csv('/content/takehome_user_engagement.csv')

# %%
file = '/content/takehome_users.csv'

# %%
import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'confidence': 0.7294372453287324, 'encoding': 'ISO-8859-1', 'language': ''}

# %%
takehome_user = pd.read_csv(file,encoding='ISO-8859-1')
takehome_user
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
takehome_user['last_session_creation_time'] = pd.to_datetime(takehome_user['last_session_creation_time'])

# %%
takehome_user
# Out:
#        object_id        creation_time               name  \
# 0              1  2014-04-22 03:53:30     Clausen August
# 1              2  2013-11-15 03:45:04      Poole Matthew
# 2              3  2013-03-19 23:14:52  Bottrill Mitchell
# 3              4  2013-05-21 08:09:28    Clausen Nicklas
# 4              5  2013-01-17 10:14:20          Raw Grace
# ...          ...                  ...                ...
# 11995      11996  2013-09-06 06:14:15       Meier Sophia
# 11996      11997  2013-01-10 18:28:37      Fisher Amelie
# 11997      11998  2014-04-27 12:45:16        Haynes Jake
# 11998      11999  2012-05-31 11:55:59       Faber Annett
# 11999      12000  2014-01-26 08:57:12         Lima Thaís
#
#                             email     creation_source  \
# 0        AugustCClausen@yahoo.com        GUEST_INVITE
# 1          MatthewPoole@gustr.com          ORG_INVITE
# 2      MitchellBottrill@gustr.com          ORG_INVITE
# 3       NicklasSClausen@yahoo.com        GUEST_INVITE
# ...

# %%
import matplotlib.pyplot as plt

# %%
len(takehome_user['name'].unique())
# Out:
# 11355

# %%
df.head(5)
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %%
df['time_stamp'] = pd.to_datetime(df['time_stamp'])

# %%
df['user_id'].value_counts().nlargest(10)
# Out:
# 3623    606
# 906     600
# 1811    593
# 7590    590
# 8068    585
# 9402    581
# 4022    580
# 3269    566
# 9312    547
# 7210    545
# Name: user_id, dtype: int64

# %%
df.resample('W',on ='time_stamp').visited.sum().plot.bar()

# %%
newdf = df.groupby([pd.Grouper(key='time_stamp', freq='W'), 'user_id']).visited.sum()

# %%
newdf = pd.DataFrame(newdf)

# %%
final = newdf.query('visited>3')

# %%
final
# Out:
#                     visited
# time_stamp user_id
# 2012-06-17 728            4
# 2012-07-08 69             4
# 2012-07-15 510            5
#            1280           4
#            6978           4
# ...                     ...
# 2014-06-01 11895          7
#            11924          7
#            11959          4
#            11967          4
#            11969          5
#
# [24444 rows x 1 columns]

# %%
final.reset_index('time_stamp',inplace=True)

# %%
customerids = final.index.to_list()

# %%
customerids = pd.DataFrame(customerids)

# %%
customerids.rename(columns={0:'customerids'},inplace=True)
customerids
# Out:
#        customerids
# 0              728
# 1               69
# 2              510
# 3             1280
# 4             6978
# ...            ...
# 24439        11895
# 24440        11924
# 24441        11959
# 24442        11967
# 24443        11969
#
# [24444 rows x 1 columns]

# %%
customerids
# Out:
#        customerids
# 0              728
# 1               69
# 2              510
# 3             1280
# 4             6978
# ...            ...
# 24439        11895
# 24440        11924
# 24441        11959
# 24442        11967
# 24443        11969
#
# [24444 rows x 1 columns]

# %%
customers = customerids['customerids'].unique()

# %%
customersorg = takehome_user['org_id'].unique()

# %%
customers = pd.DataFrame(customers)

# %%
takehome_user['creation_source'].value_counts().plot.bar()

# %%
### from we can observe that most adopted users are being invited from org_invite

# %% [markdown]
# ### from here  we can observe that most adopted users are being invited from org_invite
